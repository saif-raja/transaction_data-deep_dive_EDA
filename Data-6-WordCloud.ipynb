# %%
import pandas as pd
import numpy as np

pd.options.mode.use_inf_as_na = True
# pd.set_option('')

file = 'data_cleaned\\Data_1-Cleaned.csv'
df = pd.read_csv(file)
df
# Out:
#          Invoice_No Product_Code  Cust_ID         Invoice_Date Invoice_Status  \
# 0            489434        21232  13085.0  2009-01-12 07:45:00              F
# 1            489434        21523  13085.0  2009-01-12 07:45:00              F
# 2            489434        21871  13085.0  2009-01-12 07:45:00              F
# 3            489434        22041  13085.0  2009-01-12 07:45:00              F
# 4            489434        22064  13085.0  2009-01-12 07:45:00              F
# ...             ...          ...      ...                  ...            ...
# 1021414      581587        22899  12680.0  2011-09-12 12:50:00              F
# 1021415      581587        23254  12680.0  2011-09-12 12:50:00              F
# 1021416      581587        23255  12680.0  2011-09-12 12:50:00              F
# 1021417      581587        23256  12680.0  2011-09-12 12:50:00              F
# 1021418      581587         POST  12680.0  2011-09-12 12:50:00              F
#
# ...

# %%
all_text = " ".join(df['Product_Desc'].astype(str).to_list())
# print(all_text)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

ignore_words = ""
ignore_words_list = ignore_words.split()

STOPWORDS.update(ignore_words_list)
wordcloud = WordCloud(background_color="white" , width= 1000 , height= 600 ).generate(all_text)

plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
print(WordCloud.__doc__)
# Out:
# Word cloud object for generating and drawing.
#
#     Parameters
#     ----------
#     font_path : string
#         Font path to the font that will be used (OTF or TTF).
#         Defaults to DroidSansMono path on a Linux machine. If you are on
#         another OS or don't have this font, you need to adjust this path.
#
#     width : int (default=400)
#         Width of the canvas.
#
#     height : int (default=200)
#         Height of the canvas.
#
#     prefer_horizontal : float (default=0.90)
#         The ratio of times to try horizontal fitting as opposed to vertical.
#         If prefer_horizontal < 1, the algorithm will try rotating the word
#         if it doesn't fit. (There is currently no built-in way to get only
#         vertical words.)
#
#     mask : nd-array or None (default=None)
#         If not None, gives a binary mask on where to draw words. If mask is not
#         None, width and height will be ignored and the shape of mask will be
# ...
